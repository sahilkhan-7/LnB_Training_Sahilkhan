# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Loading the datasets
prep_df = pd.read_csv('climate_precip.csv')
temp_df = pd.read_csv('climate_temp.csv')

# %%
print(f'Shape of the precipitaion data: {prep_df.shape}')
print(f'Shape of the temperature data: {temp_df.shape}')
# Out:
# Shape of the precipitaion data: (151110, 29)
# Shape of the temperature data: (127020, 21)

# %%
pd.set_option('display.max_columns', 100)

# %%
# Overview of the datasets 
# prep_df.sample(5)
prep_df.head(5)
# Out:
#              STATION            STATION_NAME      DATE  DLY-PRCP-25PCTL  \
# 0  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100101            -6.66
# 1  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100102            -6.66
# 2  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100103            -6.66
# 3  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100104            -6.66
# 4  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100105            -6.66
#
#    DLY-SNWD-25PCTL  DLY-SNOW-25PCTL  DLY-PRCP-50PCTL  DLY-SNWD-50PCTL  \
# 0             -666            -66.6            -6.66             -666
# 1             -666            -66.6            -6.66             -666
# 2             -666            -66.6            -6.66             -666
# 3            -9999          -9999.0            -6.66            -9999
# 4            -9999          -9999.0            -6.66            -9999
#
#    DLY-SNOW-50PCTL  DLY-PRCP-75PCTL  DLY-SNWD-75PCTL  DLY-SNOW-75PCTL  \
# ...

# %%
temp_df.head()
# Out:
#              STATION            STATION_NAME ELEVATION  LATITUDE   LONGITUDE  \
# 0  GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806  -116.03694
# 1  GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806  -116.03694
# 2  GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806  -116.03694
# 3  GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806  -116.03694
# 4  GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806  -116.03694
#
#        DATE  DLY-CLDD-BASE45  DLY-CLDD-BASE50  DLY-CLDD-BASE55  \
# 0  20100101                6                2            -7777
# 1  20100102                6                2                1
# 2  20100103                6                2                1
# 3  20100104                6                2                1
# 4  20100105                6                2                1
#
#    DLY-CLDD-BASE57  DLY-CLDD-BASE60  DLY-CLDD-NORMAL  DLY-CLDD-BASE70  \
# ...

# %%
# GEtting the info about the dataset and their columns
print('Info of the precipitaion dataset:')
print(prep_df.info())
# print('Info of the temperature dataset:')
# print(temp_df.info())
# Out:
# Info of the precipitaion dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151110 entries, 0 to 151109
# Data columns (total 29 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   STATION                  151110 non-null  object
#  1   STATION_NAME             151110 non-null  object
#  2   DATE                     151110 non-null  int64
#  3   DLY-PRCP-25PCTL          151110 non-null  float64
#  4   DLY-SNWD-25PCTL          151110 non-null  int64
#  5   DLY-SNOW-25PCTL          151110 non-null  float64
#  6   DLY-PRCP-50PCTL          151110 non-null  float64
#  7   DLY-SNWD-50PCTL          151110 non-null  int64
#  8   DLY-SNOW-50PCTL          151110 non-null  float64
#  9   DLY-PRCP-75PCTL          151110 non-null  float64
#  10  DLY-SNWD-75PCTL          151110 non-null  int64
#  11  DLY-SNOW-75PCTL          151110 non-null  float64
#  12  MTD-PRCP-NORMAL          151110 non-null  float64
# ...

# %%
# Statistical summary of each dataset
prep_df.describe()
# Out:
#                DATE  DLY-PRCP-25PCTL  DLY-SNWD-25PCTL  DLY-SNOW-25PCTL  \
# count  1.511100e+05    151110.000000    151110.000000    151110.000000
# mean   2.010067e+07     -1983.400927     -9099.834584     -8477.923237
# std    3.450030e+02      3984.261185      2786.079371      3579.071334
# min    2.010010e+07     -9999.000000     -9999.000000     -9999.000000
# 25%    2.010040e+07        -6.660000     -9999.000000     -9999.000000
# 50%    2.010070e+07        -6.660000     -9999.000000     -9999.000000
# 75%    2.010100e+07         0.060000     -9999.000000     -9999.000000
# max    2.010123e+07         0.290000        40.000000         2.000000
#
#        DLY-PRCP-50PCTL  DLY-SNWD-50PCTL  DLY-SNOW-50PCTL  DLY-PRCP-75PCTL  \
# count    151110.000000    151110.000000    151110.000000    151110.000000
# mean      -1983.332954     -9099.703084     -8477.890501     -1983.185442
# std        3984.295025      2786.509451      3579.148894      3984.368470
# ...

# %%
temp_df.describe()
# Out:
#                DATE  DLY-CLDD-BASE45  DLY-CLDD-BASE50  DLY-CLDD-BASE55  \
# count  1.270200e+05    127020.000000    127020.000000    127020.000000
# mean   2.010067e+07      -305.681680      -571.357164     -1364.776594
# std    3.450032e+02      1550.917511      2050.944179      2968.682933
# min    2.010010e+07     -7777.000000     -7777.000000     -7777.000000
# 25%    2.010040e+07         7.000000         3.000000         1.000000
# 50%    2.010070e+07        14.000000         9.000000         5.000000
# 75%    2.010100e+07        23.000000        18.000000        13.000000
# max    2.010123e+07        58.000000        53.000000        48.000000
#
#        DLY-CLDD-BASE57  DLY-CLDD-BASE60  DLY-CLDD-NORMAL  DLY-CLDD-BASE70  \
# count    127020.000000    127020.000000    127020.000000    127020.000000
# mean      -1610.030515     -1993.233766     -2300.983097     -2409.871020
# std        3159.342811      3401.256167      3553.088077      3598.276966
# ...

# %%
# Checking is there any missing values in the datasets
prep_df.isnull().sum()
# Out:
# STATION                    0
# STATION_NAME               0
# DATE                       0
# DLY-PRCP-25PCTL            0
# DLY-SNWD-25PCTL            0
# DLY-SNOW-25PCTL            0
# DLY-PRCP-50PCTL            0
# DLY-SNWD-50PCTL            0
# DLY-SNOW-50PCTL            0
# DLY-PRCP-75PCTL            0
# DLY-SNWD-75PCTL            0
# DLY-SNOW-75PCTL            0
# MTD-PRCP-NORMAL            0
# MTD-SNOW-NORMAL            0
# YTD-PRCP-NORMAL            0
# YTD-SNOW-NORMAL            0
# DLY-PRCP-PCTALL-GE001HI    0
# DLY-PRCP-PCTALL-GE010HI    0
# DLY-PRCP-PCTALL-GE050HI    0
# DLY-PRCP-PCTALL-GE100HI    0
# DLY-SNWD-PCTALL-GE001WI    0
# DLY-SNWD-PCTALL-GE010WI    0
# DLY-SNWD-PCTALL-GE003WI    0
# DLY-SNWD-PCTALL-GE005WI    0
# DLY-SNOW-PCTALL-GE001TI    0
# DLY-SNOW-PCTALL-GE010TI    0
# DLY-SNOW-PCTALL-GE100TI    0
# DLY-SNOW-PCTALL-GE030TI    0
# DLY-SNOW-PCTALL-GE050TI    0
# dtype: int64

# %%
temp_df.isnull().sum()
# Out:
# STATION            0
# STATION_NAME       0
# ELEVATION          0
# LATITUDE           0
# LONGITUDE          0
# DATE               0
# DLY-CLDD-BASE45    0
# DLY-CLDD-BASE50    0
# DLY-CLDD-BASE55    0
# DLY-CLDD-BASE57    0
# DLY-CLDD-BASE60    0
# DLY-CLDD-NORMAL    0
# DLY-CLDD-BASE70    0
# DLY-CLDD-BASE72    0
# DLY-HTDD-BASE40    0
# DLY-HTDD-BASE45    0
# DLY-HTDD-BASE50    0
# DLY-HTDD-BASE55    0
# DLY-HTDD-BASE57    0
# DLY-HTDD-BASE60    0
# DLY-HTDD-NORMAL    0
# dtype: int64

# %%
x = prep_df.loc[prep_df['STATION'] == 'GHCND:USC00045721', :]
x # subset of the data
# Out:
#                 STATION            STATION_NAME      DATE  DLY-PRCP-25PCTL  \
# 1460  GHCND:USC00045721  MITCHELL CAVERNS CA US  20100101             0.04
# 1461  GHCND:USC00045721  MITCHELL CAVERNS CA US  20100102             0.05
# 1462  GHCND:USC00045721  MITCHELL CAVERNS CA US  20100103             0.05
# 1463  GHCND:USC00045721  MITCHELL CAVERNS CA US  20100104             0.05
# 1464  GHCND:USC00045721  MITCHELL CAVERNS CA US  20100105             0.05
# ...                 ...                     ...       ...              ...
# 1820  GHCND:USC00045721  MITCHELL CAVERNS CA US  20101227             0.04
# 1821  GHCND:USC00045721  MITCHELL CAVERNS CA US  20101228             0.04
# 1822  GHCND:USC00045721  MITCHELL CAVERNS CA US  20101229             0.04
# 1823  GHCND:USC00045721  MITCHELL CAVERNS CA US  20101230             0.04
# 1824  GHCND:USC00045721  MITCHELL CAVERNS CA US  20101231             0.04
#
# ...

# %%
x.STATION.unique(), x.STATION_NAME.unique()
# Out:
# (array(['GHCND:USC00045721'], dtype=object),
#  array(['MITCHELL CAVERNS CA US'], dtype=object))

# %%
pd.merge(prep_df, x, on='STATION', how='inner')
# Out:
#                   STATION          STATION_NAME_x    DATE_x  \
# 0       GHCND:USC00045721  MITCHELL CAVERNS CA US  20100101
# 1       GHCND:USC00045721  MITCHELL CAVERNS CA US  20100101
# 2       GHCND:USC00045721  MITCHELL CAVERNS CA US  20100101
# 3       GHCND:USC00045721  MITCHELL CAVERNS CA US  20100101
# 4       GHCND:USC00045721  MITCHELL CAVERNS CA US  20100101
# ...                   ...                     ...       ...
# 133220  GHCND:USC00045721  MITCHELL CAVERNS CA US  20101231
# 133221  GHCND:USC00045721  MITCHELL CAVERNS CA US  20101231
# 133222  GHCND:USC00045721  MITCHELL CAVERNS CA US  20101231
# 133223  GHCND:USC00045721  MITCHELL CAVERNS CA US  20101231
# 133224  GHCND:USC00045721  MITCHELL CAVERNS CA US  20101231
#
#         DLY-PRCP-25PCTL_x  DLY-SNWD-25PCTL_x  DLY-SNOW-25PCTL_x  \
# 0                    0.04               -666              -66.6
# 1                    0.04               -666              -66.6
# ...

# %%
pd.merge(prep_df, x, on='DATE', how='inner')
# Out:
#                 STATION_x          STATION_NAME_x      DATE  \
# 0       GHCND:USC00049099  TWENTYNINE PALMS CA US  20100101
# 1       GHCND:USC00049099  TWENTYNINE PALMS CA US  20100102
# 2       GHCND:USC00049099  TWENTYNINE PALMS CA US  20100103
# 3       GHCND:USC00049099  TWENTYNINE PALMS CA US  20100104
# 4       GHCND:USC00049099  TWENTYNINE PALMS CA US  20100105
# ...                   ...                     ...       ...
# 151105  GHCND:USC00046006  MOUNT WILSON CBS CA US  20101227
# 151106  GHCND:USC00046006  MOUNT WILSON CBS CA US  20101228
# 151107  GHCND:USC00046006  MOUNT WILSON CBS CA US  20101229
# 151108  GHCND:USC00046006  MOUNT WILSON CBS CA US  20101230
# 151109  GHCND:USC00046006  MOUNT WILSON CBS CA US  20101231
#
#         DLY-PRCP-25PCTL_x  DLY-SNWD-25PCTL_x  DLY-SNOW-25PCTL_x  \
# 0                   -6.66               -666              -66.6
# 1                   -6.66               -666              -66.6
# ...

# %% [markdown]
# ##### 29 columns from precipitation data, 29 columns from subset and DATE column is same so 29 + 29 - 1 = 57
# ##### And getting all 151110 rows because we are merging on DATE, and each day all the stations share climate report ...

# %%
prep_df.shape
# Out:
# (151110, 29)

# %%
# Merging entire datasets
pd.merge(prep_df, temp_df, on=['DATE', 'STATION'], how='inner')
# Out:
#                   STATION          STATION_NAME_x      DATE  DLY-PRCP-25PCTL  \
# 0       GHCND:USC00049099  TWENTYNINE PALMS CA US  20100101            -6.66
# 1       GHCND:USC00049099  TWENTYNINE PALMS CA US  20100102            -6.66
# 2       GHCND:USC00049099  TWENTYNINE PALMS CA US  20100103            -6.66
# 3       GHCND:USC00049099  TWENTYNINE PALMS CA US  20100104            -6.66
# 4       GHCND:USC00049099  TWENTYNINE PALMS CA US  20100105            -6.66
# ...                   ...                     ...       ...              ...
# 123000  GHCND:USC00046006  MOUNT WILSON CBS CA US  20101227             0.12
# 123001  GHCND:USC00046006  MOUNT WILSON CBS CA US  20101228             0.12
# 123002  GHCND:USC00046006  MOUNT WILSON CBS CA US  20101229             0.12
# 123003  GHCND:USC00046006  MOUNT WILSON CBS CA US  20101230             0.12
# 123004  GHCND:USC00046006  MOUNT WILSON CBS CA US  20101231             0.12
#
# ...

# %%
print(len(prep_df.columns))
print(len(temp_df.columns))
# Out:
# 29
# 21

# %%
# Outer join 
pd.merge(temp_df, x, on='DATE', how='outer')
# Out:
#                 STATION_x                              STATION_NAME_x  \
# 0       GHCND:USC00049099                      TWENTYNINE PALMS CA US
# 1       GHCND:USC00041244                          BUTTONWILLOW CA US
# 2       GHCND:USC00047902                         SANTA BARBARA CA US
# 3       GHCND:USC00042214                           CULVER CITY CA US
# 4       GHCND:USC00045721                      MITCHELL CAVERNS CA US
# ...                   ...                                         ...
# 127015  GHCND:USC00041912                                COLFAX CA US
# 127016  GHCND:USC00047339                          REDWOOD CITY CA US
# 127017  GHCND:USC00040943  BODIE CALIFORNIA STATE HISTORIC PARK CA US
# 127018  GHCND:USC00045032                                  LODI CA US
# 127019  GHCND:USC00046006                      MOUNT WILSON CBS CA US
#
#        ELEVATION  LATITUDE   LONGITUDE      DATE  DLY-CLDD-BASE45  \
# ...

# %%
x.shape, temp_df.shape
# Out:
# ((365, 29), (127020, 21))

# %%
# Left join of climate_temp data with subset x
pd.merge(left=temp_df, right=x, on='STATION', how='left')
# Out:
#                   STATION          STATION_NAME_x ELEVATION  LATITUDE  \
# 0       GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806
# 1       GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806
# 2       GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806
# 3       GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806
# 4       GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806
# ...                   ...                     ...       ...       ...
# 259875  GHCND:USC00046006  MOUNT WILSON CBS CA US    1740.4   34.2308
# 259876  GHCND:USC00046006  MOUNT WILSON CBS CA US    1740.4   34.2308
# 259877  GHCND:USC00046006  MOUNT WILSON CBS CA US    1740.4   34.2308
# 259878  GHCND:USC00046006  MOUNT WILSON CBS CA US    1740.4   34.2308
# 259879  GHCND:USC00046006  MOUNT WILSON CBS CA US    1740.4   34.2308
#
#          LONGITUDE    DATE_x  DLY-CLDD-BASE45  DLY-CLDD-BASE50  \
# ...

# %%
# verifying the shape of the datasets
prep_df.shape, temp_df.shape, x.shape
# Out:
# ((151110, 29), (127020, 21), (365, 29))

# %%
# Right join of climate_temp data with subset x

pd.merge(left = x, right=temp_df, on='DATE', how='right')
# Out:
#                 STATION_x          STATION_NAME_x      DATE  DLY-PRCP-25PCTL  \
# 0       GHCND:USC00045721  MITCHELL CAVERNS CA US  20100101             0.04
# 1       GHCND:USC00045721  MITCHELL CAVERNS CA US  20100102             0.05
# 2       GHCND:USC00045721  MITCHELL CAVERNS CA US  20100103             0.05
# 3       GHCND:USC00045721  MITCHELL CAVERNS CA US  20100104             0.05
# 4       GHCND:USC00045721  MITCHELL CAVERNS CA US  20100105             0.05
# ...                   ...                     ...       ...              ...
# 127015  GHCND:USC00045721  MITCHELL CAVERNS CA US  20101227             0.04
# 127016  GHCND:USC00045721  MITCHELL CAVERNS CA US  20101228             0.04
# 127017  GHCND:USC00045721  MITCHELL CAVERNS CA US  20101229             0.04
# 127018  GHCND:USC00045721  MITCHELL CAVERNS CA US  20101230             0.04
# 127019  GHCND:USC00045721  MITCHELL CAVERNS CA US  20101231             0.04
#
# ...

# %%
# set the DATE and STATION as index

a = prep_df.set_index(['DATE', 'STATION'])
b = temp_df.set_index(['DATE', 'STATION'])

# %%
a.head()
# Out:
#                                       STATION_NAME  DLY-PRCP-25PCTL  \
# DATE     STATION
# 20100101 GHCND:USC00049099  TWENTYNINE PALMS CA US            -6.66
# 20100102 GHCND:USC00049099  TWENTYNINE PALMS CA US            -6.66
# 20100103 GHCND:USC00049099  TWENTYNINE PALMS CA US            -6.66
# 20100104 GHCND:USC00049099  TWENTYNINE PALMS CA US            -6.66
# 20100105 GHCND:USC00049099  TWENTYNINE PALMS CA US            -6.66
#
#                             DLY-SNWD-25PCTL  DLY-SNOW-25PCTL  DLY-PRCP-50PCTL  \
# DATE     STATION
# 20100101 GHCND:USC00049099             -666            -66.6            -6.66
# 20100102 GHCND:USC00049099             -666            -66.6            -6.66
# 20100103 GHCND:USC00049099             -666            -66.6            -6.66
# 20100104 GHCND:USC00049099            -9999          -9999.0            -6.66
# 20100105 GHCND:USC00049099            -9999          -9999.0            -6.66
#
# ...

# %%
b.head()
# Out:
#                                       STATION_NAME ELEVATION  LATITUDE  \
# DATE     STATION
# 20100101 GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806
# 20100102 GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806
# 20100103 GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806
# 20100104 GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806
# 20100105 GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806
#
#                              LONGITUDE  DLY-CLDD-BASE45  DLY-CLDD-BASE50  \
# DATE     STATION
# 20100101 GHCND:USC00049099  -116.03694                6                2
# 20100102 GHCND:USC00049099  -116.03694                6                2
# 20100103 GHCND:USC00049099  -116.03694                6                2
# 20100104 GHCND:USC00049099  -116.03694                6                2
# 20100105 GHCND:USC00049099  -116.03694                6                2
#
# ...

# %%
a.join(b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 a.join(b)
#
# File c:\Users\khans\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:10757, in DataFrame.join(self, other, on, how, lsuffix, rsuffix, sort, validate)
#   10747     if how == "cross":
#   10748         return merge(
#   10749             self,
#   10750             other,
#    (...)
#   10755             validate=validate,
#   10756         )
# > 10757     return merge(
#   10758         self,
#   10759         other,
#   10760         left_on=on,
#   10761         how=how,
#   10762         left_index=on is None,
#   10763         right_index=True,
#   10764         suffixes=(lsuffix, rsuffix),
#   10765         sort=sort,
#   10766         validate=validate,
#   10767     )
#   10768 else:
#   10769     if on is not None:
#
# ...

# %%
a.join(b, lsuffix='_left', rsuffix='_right')
# Out:
#                                  STATION_NAME_left  DLY-PRCP-25PCTL  \
# DATE     STATION
# 20100101 GHCND:USC00049099  TWENTYNINE PALMS CA US            -6.66
# 20100102 GHCND:USC00049099  TWENTYNINE PALMS CA US            -6.66
# 20100103 GHCND:USC00049099  TWENTYNINE PALMS CA US            -6.66
# 20100104 GHCND:USC00049099  TWENTYNINE PALMS CA US            -6.66
# 20100105 GHCND:USC00049099  TWENTYNINE PALMS CA US            -6.66
# ...                                            ...              ...
# 20101227 GHCND:USC00046006  MOUNT WILSON CBS CA US             0.12
# 20101228 GHCND:USC00046006  MOUNT WILSON CBS CA US             0.12
# 20101229 GHCND:USC00046006  MOUNT WILSON CBS CA US             0.12
# 20101230 GHCND:USC00046006  MOUNT WILSON CBS CA US             0.12
# 20101231 GHCND:USC00046006  MOUNT WILSON CBS CA US             0.12
#
#                             DLY-SNWD-25PCTL  DLY-SNOW-25PCTL  DLY-PRCP-50PCTL  \
# DATE     STATION
# ...

# %%
# Concatenating the temp_df with itself along row-wise
pd.concat([a, b], axis=0)
# Out:
#                                       STATION_NAME  DLY-PRCP-25PCTL  \
# DATE     STATION
# 20100101 GHCND:USC00049099  TWENTYNINE PALMS CA US            -6.66
# 20100102 GHCND:USC00049099  TWENTYNINE PALMS CA US            -6.66
# 20100103 GHCND:USC00049099  TWENTYNINE PALMS CA US            -6.66
# 20100104 GHCND:USC00049099  TWENTYNINE PALMS CA US            -6.66
# 20100105 GHCND:USC00049099  TWENTYNINE PALMS CA US            -6.66
# ...                                            ...              ...
# 20101227 GHCND:USC00046006  MOUNT WILSON CBS CA US              NaN
# 20101228 GHCND:USC00046006  MOUNT WILSON CBS CA US              NaN
# 20101229 GHCND:USC00046006  MOUNT WILSON CBS CA US              NaN
# 20101230 GHCND:USC00046006  MOUNT WILSON CBS CA US              NaN
# 20101231 GHCND:USC00046006  MOUNT WILSON CBS CA US              NaN
#
#                             DLY-SNWD-25PCTL  DLY-SNOW-25PCTL  DLY-PRCP-50PCTL  \
# DATE     STATION
# ...

# %%
# Concatenating the teperature dataset with precipitation dataset along column-wise
# pd.concat([prep_df, temp_df], axis=1)
pd.concat([a, b], axis=1)
# Out:
#                                       STATION_NAME  DLY-PRCP-25PCTL  \
# DATE     STATION
# 20100101 GHCND:USC00049099  TWENTYNINE PALMS CA US            -6.66
# 20100102 GHCND:USC00049099  TWENTYNINE PALMS CA US            -6.66
# 20100103 GHCND:USC00049099  TWENTYNINE PALMS CA US            -6.66
# 20100104 GHCND:USC00049099  TWENTYNINE PALMS CA US            -6.66
# 20100105 GHCND:USC00049099  TWENTYNINE PALMS CA US            -6.66
# ...                                            ...              ...
# 20101227 GHCND:USC00045280                     NaN              NaN
# 20101228 GHCND:USC00045280                     NaN              NaN
# 20101229 GHCND:USC00045280                     NaN              NaN
# 20101230 GHCND:USC00045280                     NaN              NaN
# 20101231 GHCND:USC00045280                     NaN              NaN
#
#                             DLY-SNWD-25PCTL  DLY-SNOW-25PCTL  DLY-PRCP-50PCTL  \
# DATE     STATION
# ...

# %%
# pd.concat([prep_df, temp_df], axis=1, join='inner')
pd.concat([a, b], axis=1, join='inner')
# Out:
#                                       STATION_NAME  DLY-PRCP-25PCTL  \
# DATE     STATION
# 20100101 GHCND:USC00049099  TWENTYNINE PALMS CA US            -6.66
# 20100102 GHCND:USC00049099  TWENTYNINE PALMS CA US            -6.66
# 20100103 GHCND:USC00049099  TWENTYNINE PALMS CA US            -6.66
# 20100104 GHCND:USC00049099  TWENTYNINE PALMS CA US            -6.66
# 20100105 GHCND:USC00049099  TWENTYNINE PALMS CA US            -6.66
# ...                                            ...              ...
# 20101227 GHCND:USC00046006  MOUNT WILSON CBS CA US             0.12
# 20101228 GHCND:USC00046006  MOUNT WILSON CBS CA US             0.12
# 20101229 GHCND:USC00046006  MOUNT WILSON CBS CA US             0.12
# 20101230 GHCND:USC00046006  MOUNT WILSON CBS CA US             0.12
# 20101231 GHCND:USC00046006  MOUNT WILSON CBS CA US             0.12
#
#                             DLY-SNWD-25PCTL  DLY-SNOW-25PCTL  DLY-PRCP-50PCTL  \
# DATE     STATION
# ...

# %% [markdown]
# ## The dimension of the data is too vast and i cant decide which features should i take for EDA purpose.

# %%
prep_df.isnull().sum().sum(), temp_df.isnull().sum().sum()
# Out:
# (0, 0)

# %% [markdown]
# There is no missing values in the provided datasets so no need to apply imputation.

# %%
# Save the processed data
# prep_df.to_csv('processed_climate_precip.csv', index=False)
# temp_df.to_csv('processed_climate_temp.csv', index=False)
